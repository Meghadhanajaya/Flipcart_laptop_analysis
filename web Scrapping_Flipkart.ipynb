# %%
import bs4
from bs4 import BeautifulSoup as bs
import requests

# %%
link = 'https://www.flipkart.com/laptops/laptops~buybackguaranteeonlaptops/pr?sid=6bo%2Cb5g'

# %% [markdown]
# ### Data Aggregation through Web Scraping on Flipkart Website

# %%
page = requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
soup=bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
title=soup.title.text
title
# Out:
# 'Laptops Laptops - Buy Laptops Laptops Online at Best Prices In India | Flipkart.com'

# %%
page_body=soup.body
page_body
# Out:
# <body><div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill
# ...

# %%
page_head=soup.head
page_head
# Out:
# <head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><meta content="noodp" name="robots"/><link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-
# ...

# %%
p_tag=soup.p
print(p_tag)
# Out:
# <p class="_2-N8zT">Pretty good</p>

# %%
li_tag=soup.find('li')
li_tag
# Out:
# <li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li>

# %%
li_alltag=soup.find_all('li')
li_alltag
# Out:
# [<li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li>,
#  <li class="rgWa7D">4 GB DDR4 RAM</li>,
#  <li class="rgWa7D">32 bit Chrome Operating System</li>,
#  <li class="rgWa7D">29.46 cm (11.6 inch) Touchscreen Display</li>,
#  <li class="rgWa7D">Pre-installed G-suite Apps, Linux Kernel and Apps, Chrome Web Extensions, Google Play Store, HP Audio Switch, HP ePrint, HP Support Assistant, Dropbox</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">Office Home and Student 2021</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">AMD Ryzen 5 Hexa Core Processor</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
# ...

# %%
type(li_tag)
# Out:
# bs4.element.Tag

# %%
li_alltag[0]
# Out:
# <li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li>

# %%
li_alltag[1]
# Out:
# <li class="rgWa7D">4 GB DDR4 RAM</li>

# %%
li_tag.find_next_sibling()
# Out:
# <li class="rgWa7D">4 GB DDR4 RAM</li>

# %%
li_tag.find_previous()
# Out:
# <ul class="_1xgFaf"><li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li><li class="rgWa7D">4 GB DDR4 RAM</li><li class="rgWa7D">32 bit Chrome Operating System</li><li class="rgWa7D">29.46 cm (11.6 inch) Touchscreen Display</li><li class="rgWa7D">Pre-installed G-suite Apps, Linux Kernel and Apps, Chrome Web Extensions, Google Play Store, HP Audio Switch, HP ePrint, HP Support Assistant, Dropbox</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul>

# %%
ul_tag=soup.find('ul')
ul_tag
# Out:
# <ul class="col-12-12 _1MRYA1"></ul>

# %%
type(ul_tag)
# Out:
# bs4.element.Tag

# %%
ul_tag.find_next_sibling()

# %%
for tag in soup.find_all(True):
    print(tag.name)
# Out:
# html
# head
# link
# link
# link
# meta
# meta
# meta
# meta
# meta
# link
# link
# meta
# meta
# link
# link
# link
# link
# link
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# style
# link
# title
# meta
# meta
# meta
# meta
# link
# link
# meta
# meta
# script
# link
# script
# script
# script
# body
# div
# div
# div
# div
# div
# div
# div
# div
# a
# img
# a
# span
# img
# div
# form
# div
# div
# input
# button
# svg
# g
# path
# path
# input
# input
# input
# input
# input
# ul
# div
# div
# div
# div
# a
# div
# a
# span
# div
# div
# div
# div
# div
# svg
# path
# div
# div
# div
# a
# svg
# path
# span
# div
# div
# div
# div
# div
# div
# div
# div
# div
# section
# div
# div
# span
# div
# section
# div
# span
# div
# div
# span
# svg
# path
# a
# div
# div
# span
# svg
# path
# a
# section
# div
# div
# span
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# div
# ...

# %%
namel=soup.find('div', attrs={'class':'_4rR01T'})
namel
# Out:
# <div class="_4rR01T">HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11A-NA0002MU Chromebook</div>

# %%
name_all = soup.find_all('div', attrs={'class':'_4rR01T'})
name_all
# Out:
# [<div class="_4rR01T">HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11A-NA0002MU Chromebook</div>,
#  <div class="_4rR01T">ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...</div>,
#  <div class="_4rR01T">HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...</div>,
#  <div class="_4rR01T">DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light L...</div>,
#  <div class="_4rR01T">Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop</div>,
#  <div class="_4rR01T">ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...</div>,
#  <div class="_4rR01T">HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop</div>,
# ...

# %%
spec=soup.find('div',attrs={'class':'fMghEO'})
spec
# Out:
# <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li><li class="rgWa7D">4 GB DDR4 RAM</li><li class="rgWa7D">32 bit Chrome Operating System</li><li class="rgWa7D">29.46 cm (11.6 inch) Touchscreen Display</li><li class="rgWa7D">Pre-installed G-suite Apps, Linux Kernel and Apps, Chrome Web Extensions, Google Play Store, HP Audio Switch, HP ePrint, HP Support Assistant, Dropbox</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>

# %%
speca=soup.find_all('div',attrs={'class':'fMghEO'})
speca
# Out:
# [<div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li><li class="rgWa7D">4 GB DDR4 RAM</li><li class="rgWa7D">32 bit Chrome Operating System</li><li class="rgWa7D">29.46 cm (11.6 inch) Touchscreen Display</li><li class="rgWa7D">Pre-installed G-suite Apps, Linux Kernel and Apps, Chrome Web Extensions, Google Play Store, HP Audio Switch, HP ePrint, HP Support Assistant, Dropbox</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>,
#  <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li><li class="rgWa7D">8 GB DDR4 RAM</li><li class="rgWa7D">64 bit Windows 11 Operating System</li><li class="rgWa7D">512 GB SSD</li><li class="rgWa7D">39.62 cm (15.6 inch) Display</li><li class="rgWa7D">Office Home and Student 2021</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div>,
# ...

# %% [markdown]
# #project

# %%
products=[]
prices=[]
ratings=[]

# %%
#<a class="_1fQZEK" target="_blank" rel="noopener noreferrer" href="/hp-chromebook-mediatek-kompanio-500-4-gb-64-gb-emmc-storage-chrome-os-11a-na0002mu/p/itm92093a75fc716?pid=COMGYJYYA7FFRXZC&amp;lid=LSTCOMGYJYYA7FFRXZCCUJAJU&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;iid=en_HtYmf39iB8lx3GTQyfx1c%2B6ExXuDKWxF3A%2B5aeJdyfZCgvQeCfstwnLgKjt%2FdK8UpnaQA%2BdcS5hsFpp4JMm%2FIg%3D%3D&amp;ssid=ze0f8hghz40000001674803600463"><div class="MIXNux" data-tkid="ADVIEW_en_HtYmf39iB8lx3GTQyfx1c+6ExXuDKWxF3A+5aeJdyfZCgvQeCfstwnLgKjt/dK8UpnaQA+dcS5hsFpp4JMm/Ig=="><div class="_2QcLo-"><div><div class="CXW8mj" style="height: 200px; width: 200px;"><img loading="eager" class="_396cs4" alt="HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11A-NA0002MU Chromebook" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/u/m/a/-original-imagkqwzxzff6zaa.jpeg?q=70"></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input type="checkbox" class="_30VH1S" readonly=""><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg xmlns="http://www.w3.org/2000/svg" class="_1l0elc" width="16" height="16" viewBox="0 0 20 16"><path d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" class="eX72wL" stroke="#FFF" fill-rule="evenodd" opacity=".9"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11A-NA0002MU Chromebook</div><div class="gUuXy-"><span id="productRating_LSTCOMGYJYYA7FFRXZCCUJAJU_COMGYJYYA7FFRXZC_" class="_1lRcqv"><div class="_3LWZlK">3.8<img src="..." class="_1wB99o"></div></span><span class="_2_R_DZ"><span><span>5,926 Ratings&nbsp;</span><span class="_13vcmD">&amp;</span><span>&nbsp;679 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">MediaTek MediaTek Kompanio 500 Processor</li><li class="rgWa7D">4 GB DDR4 RAM</li><li class="rgWa7D">32 bit Chrome Operating System</li><li class="rgWa7D">29.46 cm (11.6 inch) Touchscreen Display</li><li class="rgWa7D">Pre-installed G-suite Apps, Linux Kernel and Apps, Chrome Web Extensions, Google Play Store, HP Audio Switch, HP ePrint, HP Support Assistant, Dropbox</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹18,999</div><div class="_3I9_wc _27UcVY">₹25,451</div><div class="_3Ay6Sb"><span>25% off</span></div></div><div class="_3tcB5a p8ucoS"><div><div class="_2Tpdn3" style="color: rgb(0, 0, 0); font-size: 12px; font-weight: 400;">Free delivery</div></div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;">Upto </div><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 700;">₹12,300</div><div class="_2Tpdn3 _18hQoS" style="color: rgb(0, 0, 0); font-size: 14px; font-style: normal; font-weight: 400;"> Off on Exchange</div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color: rgb(38, 165, 65); font-size: 14px; font-weight: 700;">Bank Offer</div></div></div></div></div></a>

# %%
for data in soup.find_all('a',attrs={'class':'_1fQZEK'}):
    name=data.find('div', attrs={'class':'_4rR01T'})
    price=data.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    rating=data.find('div',attrs={'class':'_3LWZlK'})
    
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text) if type(rating)==bs4.element.Tag else ratings.append('Nan')

# %%
products
# Out:
# ['HP Chromebook MediaTek Kompanio 500 - (4 GB/64 GB EMMC Storage/Chrome OS) 11A-NA0002MU Chromebook',
#  'ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...',
#  'HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...',
#  'DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light L...',
#  'Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop',
#  'ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...',
#  'HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop',
#  'MSI Crosshair 15 Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeForce RTX 3...',
#  'ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ522WS Thin and Light La...',
# ...

# %% [markdown]
# ### Counting data

# %%
prices
# Out:
# ['₹18,999',
#  '₹32,990',
#  '₹49,990',
#  '₹39,990',
#  '₹25,990',
#  '₹52,990',
#  '₹35,990',
#  '₹1,14,990',
#  '₹45,990',
#  '₹23,990',
#  '₹29,990',
#  '₹40,990',
#  '₹58,490',
#  '₹39,990',
#  '₹38,990',
#  '₹74,790',
#  '₹33,599',
#  '₹48,990',
#  '₹54,990',
#  '₹52,990',
#  '₹25,990',
#  '₹58,899',
#  '₹19,990',
#  '₹76,990']

# %%
ratings
# Out:
# ['3.8',
#  '4.3',
#  '4.4',
#  '4.1',
#  '4.1',
#  '4.4',
#  '4.2',
#  '4.4',
#  '4.2',
#  '4.1',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.1',
#  '4.2',
#  '4.5',
#  '4.1',
#  '4.4',
#  '4',
#  '3.5',
#  '4.2',
#  '4.2',
#  '3.8',
#  '4.4']

# %%
len(ratings)
# Out:
# 24

# %%
len(products)
# Out:
# 24

# %%
len(prices)
# Out:
# 24

# %%
import pandas as pd

# %% [markdown]
# ### Data creation

# %%
df=pd.DataFrame({'Product_name': products, 'Prices': prices, 'Ratings':ratings })
print(df)
# Out:
#                                          Product_name     Prices Ratings
# 0   HP Chromebook MediaTek Kompanio 500 - (4 GB/64...    ₹18,999     3.8
# 1   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹32,990     4.3
# 2   HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...    ₹49,990     4.4
# 3   DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹39,990     4.1
# 4   Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...    ₹25,990     4.1
# 5   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...    ₹52,990     4.4
# 6   HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,990     4.2
# 7   MSI Crosshair 15 Core i7 12th Gen - (16 GB/1 T...  ₹1,14,990     4.4
# 8   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...    ₹45,990     4.2
# 9   ASUS VivoBook 14 (2021) Celeron Dual Core - (4...    ₹23,990     4.1
# 10  HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...    ₹29,990     4.1
# 11  HP 14s Intel Core i3 11th Gen - (8 GB/512 GB S...    ₹40,990     4.2
# ...

# %% [markdown]
# ### Checking null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_name  24 non-null     object
#  1   Prices        24 non-null     object
#  2   Ratings       24 non-null     object
# dtypes: object(3)
# memory usage: 704.0+ bytes

# %%
# Observation _ price column, data type

# %%
df['Prices']=df['Prices'].str.lstrip('₹')

# %%
df['Prices']
# Out:
# 0       18,999
# 1       32,990
# 2       49,990
# 3       39,990
# 4       25,990
# 5       52,990
# 6       35,990
# 7     1,14,990
# 8       45,990
# 9       23,990
# 10      29,990
# 11      40,990
# 12      58,490
# 13      39,990
# 14      38,990
# 15      74,790
# 16      33,599
# 17      48,990
# 18      54,990
# 19      52,990
# 20      25,990
# 21      58,899
# 22      19,990
# 23      76,990
# Name: Prices, dtype: object

# %%
df['Prices']=df['Prices'].replace({',':''}, regex=True)

# %%
df['Prices']
# Out:
# 0      18999
# 1      32990
# 2      49990
# 3      39990
# 4      25990
# 5      52990
# 6      35990
# 7     114990
# 8      45990
# 9      23990
# 10     29990
# 11     40990
# 12     58490
# 13     39990
# 14     38990
# 15     74790
# 16     33599
# 17     48990
# 18     54990
# 19     52990
# 20     25990
# 21     58899
# 22     19990
# 23     76990
# Name: Prices, dtype: object

# %%
df['Prices'] = df['Prices'].astype(float)

# %%
df.dtypes
# Out:
# Product_name     object
# Prices          float64
# Ratings          object
# dtype: object

# %%
df['Ratings'] = df['Ratings'].astype(float)

# %%
df.dtypes
# Out:
# Product_name     object
# Prices          float64
# Ratings         float64
# dtype: object

# %%
df['Product_name']=df['Product_name'].str.split('-').str[0]

# %%
df['Product_name']
# Out:
# 0                  HP Chromebook MediaTek Kompanio 500
# 1             ASUS VivoBook 15 (2022) Core i3 10th Gen
# 2                  HP Pavilion Ryzen 5 Hexa Core AMD R5
# 3                         DELL Vostro Core i3 11th Gen
# 4                       Lenovo Intel Celeron Dual Core
# 5     ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...
# 6                        HP 14s Intel Core i3 11th Gen
# 7                    MSI Crosshair 15 Core i7 12th Gen
# 8                    ASUS Vivobook 15 Core i5 11th Gen
# 9            ASUS VivoBook 14 (2021) Celeron Dual Core
# 10                          HP Ryzen 3 Dual Core 3250U
# 11                       HP 14s Intel Core i3 11th Gen
# 12     Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core AMD R5
# 13                      RedmiBook Pro Core i5 11th Gen
# 14     ASUS VivoBook 14 (2022) Ryzen 5 Quad Core AMD R5
# 15    ASUS Vivobook S14 OLED (2022) Intel EVO Core i...
# 16                      Lenovo V15 G2 Core i3 11th Gen
# ...

# %%
df
# Out:
#                                          Product_name    Prices  Ratings
# 0                HP Chromebook MediaTek Kompanio 500    18999.0      3.8
# 1           ASUS VivoBook 15 (2022) Core i3 10th Gen    32990.0      4.3
# 2                HP Pavilion Ryzen 5 Hexa Core AMD R5   49990.0      4.4
# 3                       DELL Vostro Core i3 11th Gen    39990.0      4.1
# 4                     Lenovo Intel Celeron Dual Core    25990.0      4.1
# 5   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...   52990.0      4.4
# 6                      HP 14s Intel Core i3 11th Gen    35990.0      4.2
# 7                  MSI Crosshair 15 Core i7 12th Gen   114990.0      4.4
# 8                  ASUS Vivobook 15 Core i5 11th Gen    45990.0      4.2
# 9          ASUS VivoBook 14 (2021) Celeron Dual Core    23990.0      4.1
# 10                        HP Ryzen 3 Dual Core 3250U    29990.0      4.1
# 11                     HP 14s Intel Core i3 11th Gen    40990.0      4.2
# ...

# %%
df.to_csv('Laptop Data.csv', index=False)

# %%
loaded_csv=pd.read_csv('Laptop Data.csv')

# %%
loaded_csv
# Out:
#                                          Product_name    Prices  Ratings
# 0                HP Chromebook MediaTek Kompanio 500    18999.0      3.8
# 1           ASUS VivoBook 15 (2022) Core i3 10th Gen    32990.0      4.3
# 2                HP Pavilion Ryzen 5 Hexa Core AMD R5   49990.0      4.4
# 3                       DELL Vostro Core i3 11th Gen    39990.0      4.1
# 4                     Lenovo Intel Celeron Dual Core    25990.0      4.1
# 5   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...   52990.0      4.4
# 6                      HP 14s Intel Core i3 11th Gen    35990.0      4.2
# 7                  MSI Crosshair 15 Core i7 12th Gen   114990.0      4.4
# 8                  ASUS Vivobook 15 Core i5 11th Gen    45990.0      4.2
# 9          ASUS VivoBook 14 (2021) Celeron Dual Core    23990.0      4.1
# 10                        HP Ryzen 3 Dual Core 3250U    29990.0      4.1
# 11                     HP 14s Intel Core i3 11th Gen    40990.0      4.2
# ...

# %% [markdown]
# ### Web Scraping:
# Identifed & scraped data from the Flipkart website, such as product details, ratings, and prices.Utilize web scraping techniques using Python libraries like BeautifulSoup the desired information from the website.Stored the scraped data in a structured list of dictionaries for further processing.

# %% [markdown]
# ### Data Cleaning:
#
# Perform data cleaning and preprocessing to ensure the quality and consistency of the scraped data.
# Handle missing values, duplicate entries, inconsistent formatting, and any other data quality issues.
# Convert data types.

# %% [markdown]
# ### CSV Data Creation:
#
# Create a CSV (Comma-Separated Values) file to store the cleaned data.
# Use libraries such as pandas in Python to write the cleaned data into a CSV file.
# Defined appropriate column names for the CSV file based on the data.
